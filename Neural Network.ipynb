# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Collecting sklearn
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Requirement already satisfied, skipping upgrade: scikit-learn in /Users/Jo/anaconda3/lib/python3.7/site-packages (from sklearn) (0.21.2)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/Jo/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /Users/Jo/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.16.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /Users/Jo/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.3.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Stored in directory: /Users/Jo/Library/Caches/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Users/Jo/anaconda3/envs/PythonData/lib/python3.6/site-packages (0.14.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_ss', 'koi_period', 'koi_time0bk', 'koi_impact', 'koi_duration','koi_depth','koi_prad','koi_teq', 'koi_insol','koi_model_snr', 'koi_tce_plnt_num', 'koi_steff','koi_slogg','koi_srad','ra', 'dec',
       'koi_kepmag']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
target = df["koi_disposition"]
target_names = ["CONFIRMED", "FALSE POSITIVE","CANDIDATE"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(selected_features, target, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_ss  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 6122              0    6.768901   133.077240       0.150       3.61600
# 6370              1    0.733726   132.020050       0.291       2.30900
# 2879              0    7.652707   134.460380       0.970      79.89690
# 107               0    7.953547   174.662240       0.300       2.63120
# 29                0    4.959319   172.258529       0.831       2.22739
#
#       koi_depth  koi_prad  koi_teq  koi_insol  koi_model_snr  \
# 6122      123.1      1.24     1017     253.30           10.8
# 6370      114.6      0.86     1867    2891.64           13.8
# 2879      641.1      3.21      989     226.81          254.3
# 107       875.4      2.25      696      55.37           38.4
# 29       9802.0     12.21     1103     349.40          696.5
#
#       koi_tce_plnt_num  koi_steff  koi_slogg  koi_srad         ra        dec  \
# 6122                 1       5737      4.327     1.125  294.40472  39.351681
# 6370                 1       5855      4.578     0.797  284.50391  42.463860
# 2879                 1       6328      4.481     0.963  295.50211  38.983540
# 107                  1       4768      4.536     0.779  291.15878  40.750271
# 29                   1       5712      4.359     1.082  292.16705  48.727589
#
#       koi_kepmag
# 6122      14.725
# 6370      15.770
# 2879      13.099
# 107       15.660
# 29        15.263

# %%
type(y_train[0])
# Out:
# str

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
X_train_scaled.shape[1]
# Out:
# 17

# %%
y_train_categorical.shape[1]
# Out:
# 3

# %% [markdown]
# # Train the Model

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=17))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train_scaled, y_train_categorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
#  - 1s - loss: 0.7612 - accuracy: 0.6376
# Epoch 2/100
#  - 0s - loss: 0.6638 - accuracy: 0.7034
# Epoch 3/100
#  - 0s - loss: 0.6385 - accuracy: 0.7150
# Epoch 4/100
#  - 0s - loss: 0.6234 - accuracy: 0.7219
# Epoch 5/100
#  - 0s - loss: 0.6065 - accuracy: 0.7259
# Epoch 6/100
#  - 0s - loss: 0.5978 - accuracy: 0.7303
# Epoch 7/100
#  - 0s - loss: 0.5876 - accuracy: 0.7356
# Epoch 8/100
#  - 0s - loss: 0.5790 - accuracy: 0.7351
# Epoch 9/100
#  - 0s - loss: 0.5711 - accuracy: 0.7410
# Epoch 10/100
#  - 0s - loss: 0.5674 - accuracy: 0.7435
# Epoch 11/100
#  - 0s - loss: 0.5639 - accuracy: 0.7444
# Epoch 12/100
#  - 0s - loss: 0.5567 - accuracy: 0.7463
# Epoch 13/100
#  - 0s - loss: 0.5474 - accuracy: 0.7522
# Epoch 14/100
#  - 0s - loss: 0.5430 - accuracy: 0.7566
# Epoch 15/100
#  - 0s - loss: 0.5362 - accuracy: 0.7599
# Epoch 16/100
#  - 0s - loss: 0.5298 - accuracy: 0.7608
# Epoch 17/100
#  - 0s - loss: 0.5294 - accuracy: 0.7681
# Epoch 18/100
#  - 0s - loss: 0.5271 - accuracy: 0.7612
# Epoch 19/100
#  - 0s - loss: 0.5168 - accuracy: 0.7656
# Epoch 20/100
#  - 0s - loss: 0.5187 - accuracy: 0.7641
# Epoch 21/100
#  - 0s - loss: 0.5118 - accuracy: 0.7673
# Epoch 22/100
#  - 0s - loss: 0.5045 - accuracy: 0.7698
# Epoch 23/100
#  - 0s - loss: 0.5007 - accuracy: 0.7717
# Epoch 24/100
#  - 0s - loss: 0.4943 - accuracy: 0.7759
# Epoch 25/100
#  - 0s - loss: 0.4884 - accuracy: 0.7820
# Epoch 26/100
#  - 0s - loss: 0.4886 - accuracy: 0.7736
# Epoch 27/100
#  - 0s - loss: 0.4825 - accuracy: 0.7812
# Epoch 28/100
#  - 0s - loss: 0.4788 - accuracy: 0.7849
# Epoch 29/100
#  - 0s - loss: 0.4744 - accuracy: 0.7873
# Epoch 30/100
#  - 0s - loss: 0.4678 - accuracy: 0.7906
# Epoch 31/100
#  - 0s - loss: 0.4648 - accuracy: 0.7892
# Epoch 32/100
#  - 0s - loss: 0.4623 - accuracy: 0.7923
# Epoch 33/100
#  - 0s - loss: 0.4649 - accuracy: 0.7883
# Epoch 34/100
#  - 0s - loss: 0.4524 - accuracy: 0.7982
# Epoch 35/100
#  - 0s - loss: 0.4548 - accuracy: 0.7955
# Epoch 36/100
#  - 0s - loss: 0.4450 - accuracy: 0.8009
# Epoch 37/100
#  - 0s - loss: 0.4427 - accuracy: 0.8013
# Epoch 38/100
#  - 0s - loss: 0.4372 - accuracy: 0.8100
# Epoch 39/100
#  - 0s - loss: 0.4336 - accuracy: 0.8095
# Epoch 40/100
#  - 0s - loss: 0.4335 - accuracy: 0.8076
# Epoch 41/100
#  - 0s - loss: 0.4250 - accuracy: 0.8137
# Epoch 42/100
#  - 0s - loss: 0.4215 - accuracy: 0.8148
# Epoch 43/100
#  - 0s - loss: 0.4200 - accuracy: 0.8158
# Epoch 44/100
#  - 0s - loss: 0.4142 - accuracy: 0.8146
# Epoch 45/100
#  - 0s - loss: 0.4107 - accuracy: 0.8163
# Epoch 46/100
#  - 0s - loss: 0.4081 - accuracy: 0.8240
# Epoch 47/100
#  - 0s - loss: 0.4081 - accuracy: 0.8247
# Epoch 48/100
#  - 0s - loss: 0.4028 - accuracy: 0.8241
# Epoch 49/100
#  - 0s - loss: 0.3956 - accuracy: 0.8291
# Epoch 50/100
#  - 0s - loss: 0.3947 - accuracy: 0.8282
# Epoch 51/100
#  - 0s - loss: 0.3908 - accuracy: 0.8314
# Epoch 52/100
#  - 0s - loss: 0.3943 - accuracy: 0.8240
# Epoch 53/100
#  - 0s - loss: 0.3821 - accuracy: 0.8304
# Epoch 54/100
#  - 0s - loss: 0.3787 - accuracy: 0.8360
# Epoch 55/100
#  - 0s - loss: 0.3766 - accuracy: 0.8407
# Epoch 56/100
#  - 0s - loss: 0.3757 - accuracy: 0.8411
# Epoch 57/100
#  - 0s - loss: 0.3733 - accuracy: 0.8400
# Epoch 58/100
#  - 0s - loss: 0.3692 - accuracy: 0.8407
# Epoch 59/100
#  - 0s - loss: 0.3614 - accuracy: 0.8446
# Epoch 60/100
#  - 0s - loss: 0.3613 - accuracy: 0.8486
# Epoch 61/100
#  - 0s - loss: 0.3624 - accuracy: 0.8467
# Epoch 62/100
#  - 0s - loss: 0.3532 - accuracy: 0.8493
# Epoch 63/100
#  - 0s - loss: 0.3482 - accuracy: 0.8488
# Epoch 64/100
#  - 0s - loss: 0.3498 - accuracy: 0.8493
# Epoch 65/100
#  - 0s - loss: 0.3470 - accuracy: 0.8547
# Epoch 66/100
#  - 0s - loss: 0.3400 - accuracy: 0.8598
# Epoch 67/100
#  - 0s - loss: 0.3396 - accuracy: 0.8560
# Epoch 68/100
#  - 0s - loss: 0.3373 - accuracy: 0.8558
# Epoch 69/100
#  - 0s - loss: 0.3335 - accuracy: 0.8634
# Epoch 70/100
#  - 0s - loss: 0.3295 - accuracy: 0.8604
# Epoch 71/100
#  - 0s - loss: 0.3287 - accuracy: 0.8608
# Epoch 72/100
#  - 0s - loss: 0.3251 - accuracy: 0.8661
# Epoch 73/100
#  - 0s - loss: 0.3212 - accuracy: 0.8661
# Epoch 74/100
#  - 0s - loss: 0.3199 - accuracy: 0.8692
# Epoch 75/100
#  - 0s - loss: 0.3145 - accuracy: 0.8730
# Epoch 76/100
#  - 0s - loss: 0.3130 - accuracy: 0.8730
# Epoch 77/100
#  - 0s - loss: 0.3097 - accuracy: 0.8732
# Epoch 78/100
#  - 0s - loss: 0.3036 - accuracy: 0.8745
# Epoch 79/100
#  - 0s - loss: 0.3140 - accuracy: 0.8766
# Epoch 80/100
#  - 0s - loss: 0.3010 - accuracy: 0.8756
# Epoch 81/100
#  - 0s - loss: 0.2996 - accuracy: 0.8791
# Epoch 82/100
#  - 0s - loss: 0.2968 - accuracy: 0.8827
# Epoch 83/100
#  - 0s - loss: 0.2926 - accuracy: 0.8777
# Epoch 84/100
#  - 0s - loss: 0.2878 - accuracy: 0.8856
# Epoch 85/100
#  - 0s - loss: 0.2840 - accuracy: 0.8894
# Epoch 86/100
#  - 0s - loss: 0.2937 - accuracy: 0.8842
# Epoch 87/100
#  - 0s - loss: 0.2840 - accuracy: 0.8899
# Epoch 88/100
#  - 0s - loss: 0.2798 - accuracy: 0.8867
# Epoch 89/100
#  - 0s - loss: 0.2810 - accuracy: 0.8896
# Epoch 90/100
#  - 0s - loss: 0.2764 - accuracy: 0.8930
# Epoch 91/100
#  - 0s - loss: 0.2738 - accuracy: 0.8932
# Epoch 92/100
#  - 0s - loss: 0.2744 - accuracy: 0.8888
# Epoch 93/100
#  - 0s - loss: 0.2801 - accuracy: 0.8863
# Epoch 94/100
#  - 0s - loss: 0.2720 - accuracy: 0.8907
# Epoch 95/100
#  - 0s - loss: 0.2622 - accuracy: 0.8995
# Epoch 96/100
#  - 0s - loss: 0.2654 - accuracy: 0.8972
# Epoch 97/100
#  - 0s - loss: 0.2571 - accuracy: 0.9004
# Epoch 98/100
#  - 0s - loss: 0.2516 - accuracy: 0.9020
# Epoch 99/100
#  - 0s - loss: 0.2472 - accuracy: 0.9111
# Epoch 100/100
#  - 0s - loss: 0.2480 - accuracy: 0.9046

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Loss: 0.9427918568083024, Accuracy: 0.6962242722511292

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Tune Batch Size and Number of Epochs
import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
def create_model(init_mode='uniform'):
    # define model
    model = Sequential()
    model.add(Dense(units=100, activation='relu', input_dim=17))
    model.add(Dense(units=100, activation='relu'))
    model.add(Dense(units=3, activation='softmax'))
    # compile model
    model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
    )
    return model
seed = 7
np.random.seed(seed)
batch_size = [10, 20, 40, 60, 80, 100]
epochs = [10, 50, 100]
model_CV = KerasClassifier(build_fn=create_model, epochs=epochs, 
                           batch_size=batch_size, verbose=2)
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(model_CV, param_grid, n_jobs=-1, cv=3)

# %%
grid_result=grid1.fit(X_train_scaled, y_train_categorical)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Epoch 1/50
#  - 1s - loss: 0.7456 - accuracy: 0.6468
# Epoch 2/50
#  - 1s - loss: 0.6633 - accuracy: 0.7019
# Epoch 3/50
#  - 1s - loss: 0.6343 - accuracy: 0.7130
# Epoch 4/50
#  - 1s - loss: 0.6172 - accuracy: 0.7187
# Epoch 5/50
#  - 1s - loss: 0.6046 - accuracy: 0.7271
# Epoch 6/50
#  - 1s - loss: 0.5880 - accuracy: 0.7305
# Epoch 7/50
#  - 1s - loss: 0.5813 - accuracy: 0.7406
# Epoch 8/50
#  - 1s - loss: 0.5756 - accuracy: 0.7391
# Epoch 9/50
#  - 1s - loss: 0.5654 - accuracy: 0.7471
# Epoch 10/50
#  - 1s - loss: 0.5607 - accuracy: 0.7477
# Epoch 11/50
#  - 1s - loss: 0.5573 - accuracy: 0.7465
# Epoch 12/50
#  - 1s - loss: 0.5505 - accuracy: 0.7465
# Epoch 13/50
#  - 1s - loss: 0.5412 - accuracy: 0.7475
# Epoch 14/50
#  - 1s - loss: 0.5381 - accuracy: 0.7580
# Epoch 15/50
#  - 1s - loss: 0.5306 - accuracy: 0.7572
# Epoch 16/50
#  - 1s - loss: 0.5264 - accuracy: 0.7644
# Epoch 17/50
#  - 1s - loss: 0.5259 - accuracy: 0.7656
# Epoch 18/50
#  - 1s - loss: 0.5150 - accuracy: 0.7660
# Epoch 19/50
#  - 1s - loss: 0.5115 - accuracy: 0.7704
# Epoch 20/50
#  - 1s - loss: 0.5098 - accuracy: 0.7713
# Epoch 21/50
#  - 1s - loss: 0.5075 - accuracy: 0.7671
# Epoch 22/50
#  - 1s - loss: 0.4963 - accuracy: 0.7767
# Epoch 23/50
#  - 1s - loss: 0.4962 - accuracy: 0.7776
# Epoch 24/50
#  - 1s - loss: 0.4872 - accuracy: 0.7829
# Epoch 25/50
#  - 1s - loss: 0.4831 - accuracy: 0.7847
# Epoch 26/50
#  - 1s - loss: 0.4792 - accuracy: 0.7854
# Epoch 27/50
#  - 1s - loss: 0.4760 - accuracy: 0.7845
# Epoch 28/50
#  - 1s - loss: 0.4739 - accuracy: 0.7858
# Epoch 29/50
#  - 1s - loss: 0.4679 - accuracy: 0.7912
# Epoch 30/50
#  - 1s - loss: 0.4634 - accuracy: 0.7946
# Epoch 31/50
#  - 1s - loss: 0.4594 - accuracy: 0.7948
# Epoch 32/50
#  - 1s - loss: 0.4547 - accuracy: 0.8003
# Epoch 33/50
#  - 1s - loss: 0.4483 - accuracy: 0.7969
# Epoch 34/50
#  - 1s - loss: 0.4436 - accuracy: 0.8058
# Epoch 35/50
#  - 1s - loss: 0.4408 - accuracy: 0.8066
# Epoch 36/50
#  - 1s - loss: 0.4399 - accuracy: 0.8068
# Epoch 37/50
#  - 1s - loss: 0.4328 - accuracy: 0.8119
# Epoch 38/50
#  - 1s - loss: 0.4321 - accuracy: 0.8089
# Epoch 39/50
#  - 1s - loss: 0.4271 - accuracy: 0.8108
# Epoch 40/50
#  - 1s - loss: 0.4178 - accuracy: 0.8159
# Epoch 41/50
#  - 1s - loss: 0.4188 - accuracy: 0.8173
# Epoch 42/50
#  - 1s - loss: 0.4123 - accuracy: 0.8238
# Epoch 43/50
#  - 1s - loss: 0.4101 - accuracy: 0.8200
# Epoch 44/50
#  - 1s - loss: 0.4107 - accuracy: 0.8171
# Epoch 45/50
#  - 1s - loss: 0.4068 - accuracy: 0.8238
# Epoch 46/50
#  - 1s - loss: 0.3993 - accuracy: 0.8287
# Epoch 47/50
#  - 1s - loss: 0.3995 - accuracy: 0.8318
# Epoch 48/50
#  - 1s - loss: 0.3952 - accuracy: 0.8291
# Epoch 49/50
#  - 1s - loss: 0.3872 - accuracy: 0.8323
# Epoch 50/50
#  - 1s - loss: 0.3849 - accuracy: 0.8329
# Best: 0.714476 using {'batch_size': 20, 'epochs': 50}
# 0.711234 (0.006782) with: {'batch_size': 10, 'epochs': 10}
# 0.692924 (0.002598) with: {'batch_size': 10, 'epochs': 50}
# 0.689300 (0.000475) with: {'batch_size': 10, 'epochs': 100}
# 0.711043 (0.005650) with: {'batch_size': 20, 'epochs': 10}
# 0.714476 (0.006841) with: {'batch_size': 20, 'epochs': 50}
# 0.694831 (0.011362) with: {'batch_size': 20, 'epochs': 100}
# 0.709708 (0.007121) with: {'batch_size': 40, 'epochs': 10}
# 0.705321 (0.000852) with: {'batch_size': 40, 'epochs': 50}
# 0.708564 (0.008803) with: {'batch_size': 40, 'epochs': 100}
# 0.713904 (0.005109) with: {'batch_size': 60, 'epochs': 10}
# 0.704749 (0.001743) with: {'batch_size': 60, 'epochs': 50}
# 0.700744 (0.002996) with: {'batch_size': 60, 'epochs': 100}
# 0.710090 (0.001502) with: {'batch_size': 80, 'epochs': 10}
# 0.707992 (0.010136) with: {'batch_size': 80, 'epochs': 50}
# 0.699027 (0.001667) with: {'batch_size': 80, 'epochs': 100}
# 0.710662 (0.003546) with: {'batch_size': 100, 'epochs': 10}
# 0.709136 (0.006456) with: {'batch_size': 100, 'epochs': 50}
# 0.708182 (0.001742) with: {'batch_size': 100, 'epochs': 100}

# %%
# Tune the Training Optimization Algorithm
def create_model1(optimizer='adam'):
    # define model
    model = Sequential()
    model.add(Dense(units=100, activation='relu', input_dim=17))
    model.add(Dense(units=100, activation='relu'))
    model.add(Dense(units=3, activation='softmax'))
    # compile model
    model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
    )
    return model
model_CV1 = KerasClassifier(build_fn=create_model1, epochs=50, batch_size=20, verbose=2)
optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
param_grid1 = dict(optimizer=optimizer)
grid = GridSearchCV(estimator=model_CV1, param_grid=param_grid1, n_jobs=-1, cv=3)
grid_result1 = grid.fit(X_train_scaled, y_train_categorical)

print("Best: %f using %s" % (grid_result1.best_score_, grid_result1.best_params_))
means = grid_result1.cv_results_['mean_test_score']
stds = grid_result1.cv_results_['std_test_score']
params = grid_result1.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Epoch 1/50
#  - 1s - loss: 0.7094 - accuracy: 0.6769
# Epoch 2/50
#  - 1s - loss: 0.6565 - accuracy: 0.7038
# Epoch 3/50
#  - 1s - loss: 0.6383 - accuracy: 0.7149
# Epoch 4/50
#  - 1s - loss: 0.6261 - accuracy: 0.7236
# Epoch 5/50
#  - 1s - loss: 0.6183 - accuracy: 0.7219
# Epoch 6/50
#  - 1s - loss: 0.6102 - accuracy: 0.7280
# Epoch 7/50
#  - 1s - loss: 0.6048 - accuracy: 0.7349
# Epoch 8/50
#  - 1s - loss: 0.5988 - accuracy: 0.7345
# Epoch 9/50
#  - 1s - loss: 0.5947 - accuracy: 0.7364
# Epoch 10/50
#  - 1s - loss: 0.5904 - accuracy: 0.7393
# Epoch 11/50
#  - 1s - loss: 0.5873 - accuracy: 0.7400
# Epoch 12/50
#  - 1s - loss: 0.5833 - accuracy: 0.7376
# Epoch 13/50
#  - 1s - loss: 0.5802 - accuracy: 0.7406
# Epoch 14/50
#  - 1s - loss: 0.5776 - accuracy: 0.7402
# Epoch 15/50
#  - 1s - loss: 0.5752 - accuracy: 0.7421
# Epoch 16/50
#  - 1s - loss: 0.5720 - accuracy: 0.7459
# Epoch 17/50
#  - 1s - loss: 0.5701 - accuracy: 0.7454
# Epoch 18/50
#  - 1s - loss: 0.5686 - accuracy: 0.7461
# Epoch 19/50
#  - 1s - loss: 0.5654 - accuracy: 0.7479
# Epoch 20/50
#  - 1s - loss: 0.5637 - accuracy: 0.7498
# Epoch 21/50
#  - 1s - loss: 0.5617 - accuracy: 0.7498
# Epoch 22/50
#  - 1s - loss: 0.5601 - accuracy: 0.7524
# Epoch 23/50
#  - 1s - loss: 0.5579 - accuracy: 0.7526
# Epoch 24/50
#  - 1s - loss: 0.5567 - accuracy: 0.7513
# Epoch 25/50
#  - 1s - loss: 0.5558 - accuracy: 0.7549
# Epoch 26/50
#  - 1s - loss: 0.5541 - accuracy: 0.7540
# Epoch 27/50
#  - 1s - loss: 0.5522 - accuracy: 0.7534
# Epoch 28/50
#  - 1s - loss: 0.5508 - accuracy: 0.7547
# Epoch 29/50
#  - 1s - loss: 0.5486 - accuracy: 0.7549
# Epoch 30/50
#  - 1s - loss: 0.5483 - accuracy: 0.7582
# Epoch 31/50
#  - 1s - loss: 0.5471 - accuracy: 0.7561
# Epoch 32/50
#  - 1s - loss: 0.5454 - accuracy: 0.7564
# Epoch 33/50
#  - 1s - loss: 0.5442 - accuracy: 0.7597
# Epoch 34/50
#  - 1s - loss: 0.5429 - accuracy: 0.7545
# Epoch 35/50
#  - 1s - loss: 0.5424 - accuracy: 0.7578
# Epoch 36/50
#  - 1s - loss: 0.5407 - accuracy: 0.7601
# Epoch 37/50
#  - 1s - loss: 0.5396 - accuracy: 0.7595
# Epoch 38/50
#  - 1s - loss: 0.5386 - accuracy: 0.7593
# Epoch 39/50
#  - 1s - loss: 0.5374 - accuracy: 0.7622
# Epoch 40/50
#  - 1s - loss: 0.5359 - accuracy: 0.7610
# Epoch 41/50
#  - 1s - loss: 0.5354 - accuracy: 0.7604
# Epoch 42/50
#  - 1s - loss: 0.5337 - accuracy: 0.7618
# Epoch 43/50
#  - 1s - loss: 0.5331 - accuracy: 0.7646
# Epoch 44/50
#  - 1s - loss: 0.5324 - accuracy: 0.7643
# Epoch 45/50
#  - 1s - loss: 0.5312 - accuracy: 0.7633
# Epoch 46/50
#  - 1s - loss: 0.5303 - accuracy: 0.7629
# Epoch 47/50
#  - 1s - loss: 0.5290 - accuracy: 0.7654
# Epoch 48/50
#  - 1s - loss: 0.5282 - accuracy: 0.7648
# Epoch 49/50
#  - 1s - loss: 0.5274 - accuracy: 0.7654
# Epoch 50/50
#  - 1s - loss: 0.5262 - accuracy: 0.7677
# Best: 0.717528 using {'optimizer': 'Adagrad'}
# 0.707610 (0.009840) with: {'optimizer': 'SGD'}
# 0.711234 (0.009014) with: {'optimizer': 'RMSprop'}
# 0.717528 (0.005603) with: {'optimizer': 'Adagrad'}
# 0.698074 (0.012614) with: {'optimizer': 'Adadelta'}
# 0.698074 (0.007236) with: {'optimizer': 'Adam'}
# 0.711806 (0.007292) with: {'optimizer': 'Adamax'}
# 0.685295 (0.008484) with: {'optimizer': 'Nadam'}

# %%
# Tune the Neuron Activation Function
def create_model2(activation='relu'):
    # define model
    model = Sequential()
    model.add(Dense(units=100, activation=activation, input_dim=17))
    model.add(Dense(units=100, activation=activation))
    model.add(Dense(units=3, activation='softmax'))
    # compile model
    model.compile(
    optimizer='Adagrad',
    loss='categorical_crossentropy',
    metrics=['accuracy']
    )
    return model
model_CV2 = KerasClassifier(build_fn=create_model2, epochs=50, batch_size=20, verbose=2)
activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']
param_grid2 = dict(activation=activation)
grid = GridSearchCV(estimator=model_CV2, param_grid=param_grid2, n_jobs=-1, cv=3)

grid_result2 = grid.fit(X_train_scaled, y_train_categorical)

print("Best: %f using %s" % (grid_result2.best_score_, grid_result2.best_params_))
means = grid_result2.cv_results_['mean_test_score']
stds = grid_result2.cv_results_['std_test_score']
params = grid_result2.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Epoch 1/50
#  - 1s - loss: 0.7080 - accuracy: 0.6790
# Epoch 2/50
#  - 1s - loss: 0.6498 - accuracy: 0.7118
# Epoch 3/50
#  - 1s - loss: 0.6316 - accuracy: 0.7173
# Epoch 4/50
#  - 1s - loss: 0.6200 - accuracy: 0.7263
# Epoch 5/50
#  - 1s - loss: 0.6113 - accuracy: 0.7301
# Epoch 6/50
#  - 1s - loss: 0.6033 - accuracy: 0.7330
# Epoch 7/50
#  - 1s - loss: 0.5977 - accuracy: 0.7358
# Epoch 8/50
#  - 1s - loss: 0.5926 - accuracy: 0.7345
# Epoch 9/50
#  - 1s - loss: 0.5872 - accuracy: 0.7383
# Epoch 10/50
#  - 1s - loss: 0.5842 - accuracy: 0.7385
# Epoch 11/50
#  - 1s - loss: 0.5804 - accuracy: 0.7461
# Epoch 12/50
#  - 1s - loss: 0.5775 - accuracy: 0.7419
# Epoch 13/50
#  - 1s - loss: 0.5736 - accuracy: 0.7423
# Epoch 14/50
#  - 1s - loss: 0.5713 - accuracy: 0.7429
# Epoch 15/50
#  - 1s - loss: 0.5690 - accuracy: 0.7482
# Epoch 16/50
#  - 1s - loss: 0.5661 - accuracy: 0.7479
# Epoch 17/50
#  - 1s - loss: 0.5636 - accuracy: 0.7467
# Epoch 18/50
#  - 1s - loss: 0.5616 - accuracy: 0.7480
# Epoch 19/50
#  - 1s - loss: 0.5602 - accuracy: 0.7492
# Epoch 20/50
#  - 1s - loss: 0.5571 - accuracy: 0.7517
# Epoch 21/50
#  - 1s - loss: 0.5561 - accuracy: 0.7517
# Epoch 22/50
#  - 1s - loss: 0.5542 - accuracy: 0.7515
# Epoch 23/50
#  - 1s - loss: 0.5526 - accuracy: 0.7530
# Epoch 24/50
#  - 1s - loss: 0.5515 - accuracy: 0.7538
# Epoch 25/50
#  - 1s - loss: 0.5486 - accuracy: 0.7549
# Epoch 26/50
#  - 1s - loss: 0.5487 - accuracy: 0.7564
# Epoch 27/50
#  - 1s - loss: 0.5464 - accuracy: 0.7561
# Epoch 28/50
#  - 1s - loss: 0.5447 - accuracy: 0.7559
# Epoch 29/50
#  - 1s - loss: 0.5437 - accuracy: 0.7561
# Epoch 30/50
#  - 1s - loss: 0.5417 - accuracy: 0.7564
# Epoch 31/50
#  - 1s - loss: 0.5416 - accuracy: 0.7557
# Epoch 32/50
#  - 1s - loss: 0.5395 - accuracy: 0.7599
# Epoch 33/50
#  - 1s - loss: 0.5383 - accuracy: 0.7610
# Epoch 34/50
#  - 1s - loss: 0.5370 - accuracy: 0.7574
# Epoch 35/50
#  - 1s - loss: 0.5358 - accuracy: 0.7614
# Epoch 36/50
#  - 1s - loss: 0.5350 - accuracy: 0.7614
# Epoch 37/50
#  - 1s - loss: 0.5335 - accuracy: 0.7608
# Epoch 38/50
#  - 1s - loss: 0.5327 - accuracy: 0.7610
# Epoch 39/50
#  - 1s - loss: 0.5317 - accuracy: 0.7629
# Epoch 40/50
#  - 1s - loss: 0.5310 - accuracy: 0.7583
# Epoch 41/50
#  - 1s - loss: 0.5299 - accuracy: 0.7614
# Epoch 42/50
#  - 1s - loss: 0.5287 - accuracy: 0.7629
# Epoch 43/50
#  - 1s - loss: 0.5280 - accuracy: 0.7622
# Epoch 44/50
#  - 1s - loss: 0.5271 - accuracy: 0.7627
# Epoch 45/50
#  - 1s - loss: 0.5255 - accuracy: 0.7660
# Epoch 46/50
#  - 1s - loss: 0.5245 - accuracy: 0.7648
# Epoch 47/50
#  - 1s - loss: 0.5239 - accuracy: 0.7641
# Epoch 48/50
#  - 1s - loss: 0.5229 - accuracy: 0.7643
# Epoch 49/50
#  - 1s - loss: 0.5217 - accuracy: 0.7654
# Epoch 50/50
#  - 1s - loss: 0.5211 - accuracy: 0.7646
# Best: 0.722869 using {'activation': 'relu'}
# 0.662026 (0.008773) with: {'activation': 'softmax'}
# 0.695403 (0.007842) with: {'activation': 'softplus'}
# 0.713714 (0.005013) with: {'activation': 'softsign'}
# 0.722869 (0.006828) with: {'activation': 'relu'}
# 0.709708 (0.007451) with: {'activation': 'tanh'}
# 0.684341 (0.011298) with: {'activation': 'sigmoid'}
# 0.683387 (0.013169) with: {'activation': 'hard_sigmoid'}
# 0.680908 (0.011388) with: {'activation': 'linear'}

# %%
predictions = grid.predict(X_test_scaled)
predictions=to_categorical(predictions)

from sklearn.metrics import classification_report
print(classification_report(y_test_categorical, predictions, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.48      0.42      0.45       411
# FALSE POSITIVE       0.67      0.72      0.69       484
#      CANDIDATE       0.84      0.85      0.85       853
#
#      micro avg       0.71      0.71      0.71      1748
#      macro avg       0.66      0.66      0.66      1748
#   weighted avg       0.71      0.71      0.71      1748
#    samples avg       0.71      0.71      0.71      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Neural.sav'
joblib.dump(model, 'Neural.sav')
# Out:
# ['Neural.sav']
